# %% [markdown]
# <a href="https://colab.research.google.com/github/hyui02/ESAA_assignment/blob/main/YB_0918(2)_exercises_scores_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.
# *참고*
#
# ```
# raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#             'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#             'female': [0, 1, 1, 0, 1],
#             'age': [42, 52, 36, 24, 73],
#             'preTestScore': [4, 24, 31, 2, 3],
#             'postTestScore': [25, 94, 57, 62, 70]}
# ```

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'female': [0, 1, 1, 0, 1],
            'age': [42, 52, 36, 24, 73],
            'preTestScore': [4, 24, 31, 2, 3],
            'postTestScore': [25, 94, 57, 62, 70]}

df = pd.DataFrame(raw_data, columns=['first_name', 'last_name', 'age', 'female', 'preTestScore', 'postTestScore']) #칼럼을 변수 이름으로 부여
df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
plt.scatter(x=df.preTestScore, y=df.postTestScore, s=df.age)
plt.xlabel('Pre Test Score')
plt.ylabel('Post Test Score')
plt.title('Pre Test Score vs Post Test Score (size = Age)')
plt.show()

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.scatter(x='preTestScore', y='postTestScore', s=df.postTestScore * 4.5, c='female', data=df)
plt.xlabel('Pre Test Score')
plt.ylabel('Post Test Score')
plt.title('Pre Test Score vs Post Test Score')
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# #개개인의 점수가 얼마나 향상되었는가?

# %%
df['improvement'] = df.postTestScore - df.preTestScore

df.plot(x='first_name', y='improvement', kind='bar', legend=False, color='purple')
plt.xlabel('Student')
plt.ylabel('Score Improvement (Post - Pre)')
plt.title('How much did each student improve?')
plt.show()

# %% [markdown]
# #성별을 기준으로 평균 점수 향상률이 어떻게 되는가?

# %%
df['improvement'] = df['postTestScore'] - df['preTestScore']
df['sex'] = df['female'].map({0: 'Male', 1: 'Female'})

df.groupby('sex')['improvement'].agg(['count', 'mean'])
g = df.groupby('sex')['improvement'].mean()

plt.figure(figsize=(6, 4.5))
plt.bar(g.index, g.values, color=['#e377c2', '#1f77b4'], width=0.5)
plt.xlabel('sex')
plt.ylabel('mean improvement')
plt.title('Mean improvement by sex')
plt.show()
